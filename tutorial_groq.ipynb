# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.75)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.10)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: pip>=25.2 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langchain-text-splitters<1.0.0,>=0.3.9->langchain) (25.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nahian fariha\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.0 which is incompatible.
# langchain-cohere 0.3.5 requires langchain-core<0.4.0,>=0.3.27, but you have langchain-core 1.0.0 which is incompatible.
# langchain-experimental 0.3.4 requires langchain-core<0.4.0,>=0.3.28, but you have langchain-core 1.0.0 which is incompatible.
# langchain-openai 0.2.14 requires langchain-core<0.4.0,>=0.3.27, but you have langchain-core 1.0.0 which is incompatible.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key = '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',
    model="llama-3.3-70b-versatile"
)
response = llm.invoke("The first person to land on the moon was..")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.
